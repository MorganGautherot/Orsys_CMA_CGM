# %% [markdown]
# # Le RNN avec Pytorch

# %% [markdown]
# Dans ce notebook, vous allez découvrir comment utiliser le RNN avec Pytorch pour résoudre un problème de série temporelle.
#
# Le but sera de prédire la température de Delhi au cours du temps.
#
# Vous pouvez retrouver le jeu de donneés sur [Kaggle](https://www.kaggle.com/datasets/sumanthvrao/daily-climate-time-series-data).

# %% [markdown]
# # Importation des packages

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch as torch
from torch.utils.data import Dataset
from torchsummary import summary

import matplotlib.pyplot as plt

# %% [markdown]
# # Importation des données

# %% [markdown]
# J'ai hébergé les données sur mon compte Google Drive pour vous permettre de gagner du temps et de ne pas devoir les charger sur votre session Google Colab.
#
# Vous avez seulement à ajouter un raccourci de mon Drive au votre, puis à lier votre compte Google Colab à votre compte Google Drive pour avoir accès aux données.
#
# Les données ne seront en aucun cas sur votre Drive, seul un raccourci où se situe les données sera présent.

# %% [markdown]
# ### Lier les données à votre Drive

# %% [markdown]
# Lien du drive:
#
# https://drive.google.com/drive/folders/1oYQazCKVZZiCPVP6z9R37NHtXy-faBhy?usp=sharing

# %% [markdown]
# **Cliquez** sur le lien.
#
# **Cliquez** droit sur le dossier *delhi_climate* comme sur la photo ci-dessous.

# %% [markdown]
# ![ajouter au drive delhi.png](data:image/png;base64,...)

# %% [markdown]
# **Cliquez** sur l'option *Ajouter un raccourci dans Drive*.

# %% [markdown]
# ## Lier votre compte Google Colab à votre Drive

# %% [markdown]
# **Exécutez** la cellule ci-dessous pour lier votre compte Google Drive à votre session Google Colab.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/delhi_climate/DailyDelhiClimateTrain.csv')
train.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
test = pd.read_csv('/content/drive/MyDrive/delhi_climate/DailyDelhiClimateTest.csv')
test.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1  2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2  2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3  2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4  2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %% [markdown]
# # Analyse du jeu de données

# %% [markdown]
# ##Statistiques descriptives

# %%
train.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %% [markdown]
# On peut remarquer des outliers dans la mesure de la pression pour le jeu d'entraînement.

# %%
test.describe()
# Out:
#          meantemp    humidity  wind_speed  meanpressure
# count  114.000000  114.000000  114.000000    114.000000
# mean    21.713079   56.258362    8.143924   1004.035090
# std      6.360072   19.068083    3.588049     89.474692
# min     11.000000   17.750000    1.387500     59.000000
# 25%     16.437198   39.625000    5.563542   1007.437500
# 50%     19.875000   57.750000    8.069444   1012.739316
# 75%     27.705357   71.902778   10.068750   1016.739583
# max     34.500000   95.833333   19.314286   1022.809524

# %% [markdown]
# ## Données manquantes

# %% [markdown]
# Checkez s'il y a des valeurs manquantes.

# %%
train.isna().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
test.isna().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %% [markdown]
# Aucune données manquantes.

# %% [markdown]
# ## Gestion des outliers

# %%
train['meanpressure'].sort_values()
# Out:
# 1323      -3.041667
# 1427      12.045455
# 1309     310.437500
# 1321     633.900000
# 1255     938.066667
#            ...
# 717     1022.125000
# 383     1023.000000
# 1416    1350.296296
# 1362    1352.615385
# 1182    7679.333333
# Name: meanpressure, Length: 1462, dtype: float64

# %% [markdown]
# Si une valeur est plus grande que la moyenne plus 1.5 fois l'écart type on remplace cette valeur par la valeur moyenne plus 1.5 fois l'écart type.

# %%
train['meanpressure'] = np.where(train['meanpressure']>train['meanpressure'].median()+train['meanpressure'].std()*1.5,
                                 train['meanpressure'].median()+train['meanpressure'].std()*1.5,
                                 train['meanpressure'])

# %% [markdown]
# Si une valeur est plus petite que la moyenne moins 1.5 fois l'écart type on remplace cette valeur par la valeur moyenne moins 1.5 fois l'écart type.

# %%
train['meanpressure'] = np.where(train['meanpressure']<train['meanpressure'].median()-train['meanpressure'].std()*1.5,
                                 train['meanpressure'].median()+train['meanpressure'].std()*1.5,
                                 train['meanpressure'])

# %% [markdown]
# ## Visualisation des distributions

# %%
plt.boxplot(x=train['meantemp'])
plt.show()

# %%
plt.boxplot(x=train['humidity'])
plt.show()

# %%
plt.boxplot(x=train['wind_speed'])
plt.show()

# %%
plt.boxplot(x=train['meanpressure'])
plt.show()

# %% [markdown]
# ## Visualisation des séries temporelles

# %%
plt.figure(figsize=(100,80))
fig, axs = plt.subplots(2, 2,figsize=(20,20))
axs[0, 0].plot(train['date'],train['meantemp'])
axs[0, 0].set_title('Mean temp')
axs[0, 1].plot(train['date'],train['humidity'], 'tab:orange')
axs[0, 1].set_title('Humidity')
axs[1, 0].plot(train['date'],train['wind_speed'], 'tab:green')
axs[1, 0].set_title('Wind Speed')
axs[1, 1].plot(train['date'],train['meanpressure'], 'tab:red')
axs[1, 1].set_title('MeanPressure')
plt.show()

# %% [markdown]
# # Pré traitement des données

# %% [markdown]
# Standardisation du jeu d'entraînement.

# %%
scaler_train = StandardScaler()

scaler_train.fit(train.loc[:, ["meantemp", "humidity",
                               "wind_speed", "meanpressure"]])

train_norm = train.copy()

train_norm.loc[:, ["meantemp", "humidity",
                   "wind_speed", "meanpressure"]] = scaler_train.transform(train.loc[:, ["meantemp", "humidity",
                                                                                         "wind_speed", "meanpressure"]])

test_norm = test.copy()

test_norm.loc[:, ["meantemp", "humidity",
                  "wind_speed", "meanpressure"]] = scaler_train.transform(test.loc[:, ["meantemp", "humidity",
                                                                                       "wind_speed", "meanpressure"]])

# %% [markdown]
# # Création du jeu d'entraînement temporel

# %% [markdown]
# Création du jeu de données de série temporelle avec les historiques pour chaque prédiction.

# %%
def create_temporal_dataset(df:pd.DataFrame, target:str, look_back:int=2) -> np.array:
  ''' Create a temporal dataset to predict the y a previous number of terms equal to look_back'''

  # Initialisation of the explaniables variables dataset
  x = np.zeros([df.shape[0]-look_back, look_back, df.shape[1]])
  # Initialisation of the target dataset
  y = np.zeros([df.shape[0]-look_back, 1])

  # For every target value search expainables variables for a number of terms equal to look_back
  for i in range(len(df)-look_back):
      # update x and y
      x[i, :, :] = df.iloc[i:(i+look_back), :]
      y[i, :] = df.loc[(i+look_back), target]
  return x, y

# %% [markdown]
# Pour prédire la prochaine température, on décide de prendre 3 jours d'historiques.

# %%
x_train, y_train = create_temporal_dataset(train_norm.sort_values('date').drop('date', axis=1), 'meantemp', 5)

# %%
x_train.shape
# Out:
# (1457, 5, 4)

# %%
x_test, y_test = create_temporal_dataset(test_norm.sort_values('date').drop('date', axis=1), 'meantemp', 5)

# %%
x_test.shape
# Out:
# (109, 5, 4)

# %% [markdown]
# ## Création du générateur

# %% [markdown]
# Cette fonction permet de créer un générateur Pytorch adapter à la problématique.

# %%
class CustomDataset(Dataset):
    def __init__(self, x_train, y_train):
        self.input = x_train
        self.output = y_train

    def __len__(self):
        return len(self.output)

    def __getitem__(self, idx):
        batch_input = self.input[idx, :, :]
        batch_output = self.output[idx, :]

        return batch_input, batch_output

# %%
x_training = CustomDataset(torch.from_numpy(np.float32(x_train)),
                                 torch.from_numpy(np.float32(y_train)))

# %% [markdown]
# Utilisez la fonction `DataLoader` avec `x_training` et un batch de 32.

# %%
dataloader_train = torch.utils.data.DataLoader(x_training,
                                                batch_size=32,
                                                shuffle=True)

# %% [markdown]
# Checkez les dimensions des batchs générés.

# %%
for x, y in dataloader_train:
  print(x.shape)
  print(y.shape)
  break
# Out:
# torch.Size([32, 5, 4])
# torch.Size([32, 1])

# %%
x_testing = CustomDataset(torch.from_numpy(np.float32(x_test)),
                                 torch.from_numpy(np.float32(y_test)))

# %% [markdown]
# Utilisez la fonction `DataLoader` avec `x_testing` et un batch de `len(x_testing)`.

# %%
dataloader_test = torch.utils.data.DataLoader(x_testing,
                                                batch_size=len(x_testing),
                                                shuffle=False)

# %% [markdown]
# Checkez les dimensions des données.

# %%
for x, y in dataloader_test:
  print(x.shape)
  print(y.shape)
  break
# Out:
# torch.Size([109, 5, 4])
# torch.Size([109, 1])

# %% [markdown]
# # Entraînement du modèle

# %% [markdown]
# Fonction d'entraînement.

# %%
def step(model:torch.nn.Sequential,
         opt:torch.optim,
         criterion:torch.nn.modules.loss,
         x_train:torch.Tensor,
         y_train:torch.Tensor)->tuple:
  """
  Executes a single training step for a PyTorch model.
  This function performs a forward pass to compute the model's predictions, calculates
  the loss between predictions and actual target values, computes gradients for each
  model parameter, and updates the parameters using the optimizer.

  Args:
      model (torch.nn.Sequential): The PyTorch model to train.
      optimizer (torch.optim.Optimizer): Optimizer used to update the model's parameters.
      criterion (torch.nn.modules.loss._Loss): Loss function used to compute the error.
      x_train (torch.Tensor): Input training data (features).
      y_train (torch.Tensor): Ground truth labels or target values for the training data.
  Returns:
      tuple: The updated model and the computed loss for the current step.
  """

  # Réinitialisez les gradients d'optimizer à zéro avec la méthode 'zero_grad'
  opt.zero_grad()

  # Calculez les prédiction sur le jeu d'entraînement avec la méthode 'froward'
  prediction = model.forward(x_train)

  # Calculez l'erreur de prédiction avec 'criterion'
  loss = criterion(prediction, y_train)

  # Calculez les gradients avec la méthode 'backward'
  loss.backward()

  # Mettre à jour les paramètres du modèle avec la méthode 'step'
  opt.step()

  return model, loss

# %%
def fit(model, optimizer, criterion, epoch, trainloader, testloader):
    epoch = epoch
    history_train_loss = []
    history_test_loss = []

    for e in range(epoch) :

      train_loss_batch = 0
      test_loss_batch = 0

      for x, y in trainloader:

        # mise à jour des poids avec la fonction 'step'
        model, train_loss = step(model, optimizer, criterion, x, y)

        train_loss_batch += train_loss.detach().numpy()


      for x, y in testloader:

        prediction = model.forward(x)

        test_loss = criterion(prediction, y)

        test_loss_batch += test_loss.detach().numpy()

      train_loss_batch /= len(trainloader.sampler)
      test_loss_batch /= len(testloader.sampler)

      # Sauvegarde des coûts d'entraînement avec append
      history_train_loss = np.append(history_train_loss, train_loss_batch)
      history_test_loss = np.append(history_test_loss, test_loss_batch)

      print(f'epoch : {e}/{epoch}')
      print('train_loss : '+str(np.squeeze(train_loss_batch))+ ' test_loss : '+str(np.squeeze(test_loss_batch)))
      print('-------------------------------------------------------------------------------------------------')

    return model, history_train_loss, history_test_loss

# %% [markdown]
# ## Initialisation du modèle

# %% [markdown]
# **Utilisez** la fonction `__init__` pour initialiser le modèle suivant:
# - une couche de RNN avec en utilisant les paramètres de `__init__` et avec batch_first à True.
# - une couche linéaire en utilisant les paramètres `__init__`.
#
#
# Pour la fonction `forward`:
# - D'abord initialiser `h0` qui est un vecteur de 0.
# - Ensuite utiliser `self.rnn`
# - Enfin utiliser `self.fc` en prenant seulement la dernière sortie de `out`.

# %%
# Définir le modèle RNN
class RNNModel(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNNModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # Couche RNN
        self.rnn = torch.nn.RNN(input_size, hidden_size, num_layers, batch_first=True)

        # Couche entièrement connectée pour la sortie
        self.fc = torch.nn.Linear(hidden_size, output_size)

    def forward(self, x):
        batch_size = x.size(0)
        # Initialiser l'état caché avec des zéros
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(x.device)

        # Passer les données dans la couche RNN
        out, h_n = self.rnn(x, h0)

        # Prendre la dernière sortie de la séquence
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# Utilisez la fonction `RNNModel` pour initialiser le modèle.

# %%
# Définir les dimensions d'entrée et de sortie
input_size = 4
hidden_size = 20
num_layers = 1
output_size = 1

# Initialiser le modèle
model = RNNModel(input_size, hidden_size, num_layers, output_size)

# %% [markdown]
# ## Visualisation du modèle

# %% [markdown]
# **Utilisez** la fonction `summary` pour visualiser votre modèle.

# %%
summary(model, input_size=(5, input_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#                RNN-1  [[-1, 5, 20], [-1, 2, 20]]               0
#             Linear-2                    [-1, 1]              21
# ================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.03
# ----------------------------------------------------------------

# %% [markdown]
# ## Compilation du modèle

# %% [markdown]
# Initialisez `criterion` avec la fonction `L1Loss`.
#
# Initialisez `optimizer` avec `Adam` et un learning rate de 0.001.

# %%
criterion = torch.nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# Utilisez la fonction `fit` pour entraîner le modèle.

# %%
epoch = 200

# %%
model, history_train_loss, history_test_loss = fit(model,
                                                   optimizer,
                                                   criterion,
                                                   epoch,
                                                   dataloader_train,
                                                   dataloader_test)
# Out:
# epoch : 0/200
# train_loss : 0.00058679987 test_loss : 0.008011285
# -------------------------------------------------------------------------------------------------
# epoch : 1/200
# train_loss : 0.00057844346 test_loss : 0.007926601
# -------------------------------------------------------------------------------------------------
# epoch : 2/200
# train_loss : 0.00057014724 test_loss : 0.007843416
# -------------------------------------------------------------------------------------------------
# epoch : 3/200
# train_loss : 0.00056186033 test_loss : 0.007761112
# -------------------------------------------------------------------------------------------------
# epoch : 4/200
# train_loss : 0.00055352 test_loss : 0.007678585
# -------------------------------------------------------------------------------------------------
# epoch : 5/200
# train_loss : 0.0005450784 test_loss : 0.0075948527
# -------------------------------------------------------------------------------------------------
# epoch : 6/200
# train_loss : 0.0005365083 test_loss : 0.0075117312
# -------------------------------------------------------------------------------------------------
# epoch : 7/200
# train_loss : 0.00052778295 test_loss : 0.0074297716
# -------------------------------------------------------------------------------------------------
# epoch : 8/200
# train_loss : 0.0005189298 test_loss : 0.0073445346
# -------------------------------------------------------------------------------------------------
# epoch : 9/200
# train_loss : 0.0005099569 test_loss : 0.0072559156
# -------------------------------------------------------------------------------------------------
# epoch : 10/200
# train_loss : 0.0005007831 test_loss : 0.007163814
# -------------------------------------------------------------------------------------------------
# epoch : 11/200
# train_loss : 0.00049139676 test_loss : 0.0070679565
# -------------------------------------------------------------------------------------------------
# epoch : 12/200
# train_loss : 0.0004817915 test_loss : 0.006968003
# -------------------------------------------------------------------------------------------------
# epoch : 13/200
# train_loss : 0.00047195583 test_loss : 0.0068648965
# -------------------------------------------------------------------------------------------------
# epoch : 14/200
# train_loss : 0.0004619133 test_loss : 0.0067578466
# -------------------------------------------------------------------------------------------------
# epoch : 15/200
# train_loss : 0.00045161453 test_loss : 0.0066460622
# -------------------------------------------------------------------------------------------------
# epoch : 16/200
# train_loss : 0.00044107347 test_loss : 0.0065304628
# -------------------------------------------------------------------------------------------------
# epoch : 17/200
# train_loss : 0.0004302469 test_loss : 0.00640802
# -------------------------------------------------------------------------------------------------
# epoch : 18/200
# train_loss : 0.00041919696 test_loss : 0.0062778695
# -------------------------------------------------------------------------------------------------
# epoch : 19/200
# train_loss : 0.00040795535 test_loss : 0.006141813
# -------------------------------------------------------------------------------------------------
# epoch : 20/200
# train_loss : 0.00039646562 test_loss : 0.0060003316
# -------------------------------------------------------------------------------------------------
# epoch : 21/200
# train_loss : 0.0003846714 test_loss : 0.005857458
# -------------------------------------------------------------------------------------------------
# epoch : 22/200
# train_loss : 0.00037261008 test_loss : 0.005708155
# -------------------------------------------------------------------------------------------------
# epoch : 23/200
# train_loss : 0.00036023624 test_loss : 0.0055490993
# -------------------------------------------------------------------------------------------------
# epoch : 24/200
# train_loss : 0.00034769205 test_loss : 0.0053836317
# -------------------------------------------------------------------------------------------------
# epoch : 25/200
# train_loss : 0.00033504193 test_loss : 0.0052127233
# -------------------------------------------------------------------------------------------------
# epoch : 26/200
# train_loss : 0.00032221657 test_loss : 0.005034788
# -------------------------------------------------------------------------------------------------
# epoch : 27/200
# train_loss : 0.00030927578 test_loss : 0.0048465487
# -------------------------------------------------------------------------------------------------
# epoch : 28/200
# train_loss : 0.00029626788 test_loss : 0.0046486887
# -------------------------------------------------------------------------------------------------
# epoch : 29/200
# train_loss : 0.00028332937 test_loss : 0.0044488464
# -------------------------------------------------------------------------------------------------
# epoch : 30/200
# train_loss : 0.00027066507 test_loss : 0.004261979
# -------------------------------------------------------------------------------------------------
# epoch : 31/200
# train_loss : 0.00025829574 test_loss : 0.0040762997
# -------------------------------------------------------------------------------------------------
# epoch : 32/200
# train_loss : 0.0002461149 test_loss : 0.0038871882
# -------------------------------------------------------------------------------------------------
# epoch : 33/200
# train_loss : 0.00023420008 test_loss : 0.003703844
# -------------------------------------------------------------------------------------------------
# epoch : 34/200
# train_loss : 0.0002228705 test_loss : 0.0035266809
# -------------------------------------------------------------------------------------------------
# epoch : 35/200
# train_loss : 0.00021243207 test_loss : 0.0033646137
# -------------------------------------------------------------------------------------------------
# epoch : 36/200
# train_loss : 0.00020283356 test_loss : 0.0032074435
# -------------------------------------------------------------------------------------------------
# epoch : 37/200
# train_loss : 0.00019450352 test_loss : 0.003055344
# -------------------------------------------------------------------------------------------------
# epoch : 38/200
# train_loss : 0.00018749725 test_loss : 0.002925672
# -------------------------------------------------------------------------------------------------
# epoch : 39/200
# train_loss : 0.00018170557 test_loss : 0.002823388
# -------------------------------------------------------------------------------------------------
# epoch : 40/200
# train_loss : 0.0001772873 test_loss : 0.0027397913
# -------------------------------------------------------------------------------------------------
# epoch : 41/200
# train_loss : 0.00017421907 test_loss : 0.0026720422
# -------------------------------------------------------------------------------------------------
# epoch : 42/200
# train_loss : 0.00017225908 test_loss : 0.0026183962
# -------------------------------------------------------------------------------------------------
# epoch : 43/200
# train_loss : 0.00017127962 test_loss : 0.0025764387
# -------------------------------------------------------------------------------------------------
# epoch : 44/200
# train_loss : 0.00017109662 test_loss : 0.0025444974
# -------------------------------------------------------------------------------------------------
# epoch : 45/200
# train_loss : 0.00017132584 test_loss : 0.0025306237
# -------------------------------------------------------------------------------------------------
# epoch : 46/200
# train_loss : 0.00017162194 test_loss : 0.002525312
# -------------------------------------------------------------------------------------------------
# epoch : 47/200
# train_loss : 0.0001716273 test_loss : 0.0025163162
# -------------------------------------------------------------------------------------------------
# epoch : 48/200
# train_loss : 0.00017112582 test_loss : 0.002501756
# -------------------------------------------------------------------------------------------------
# epoch : 49/200
# train_loss : 0.00017003376 test_loss : 0.002479994
# -------------------------------------------------------------------------------------------------
# epoch : 50/200
# train_loss : 0.00016836982 test_loss : 0.0024545705
# -------------------------------------------------------------------------------------------------
# epoch : 51/200
# train_loss : 0.00016627752 test_loss : 0.0024284632
# -------------------------------------------------------------------------------------------------
# epoch : 52/200
# train_loss : 0.00016393689 test_loss : 0.002406473
# -------------------------------------------------------------------------------------------------
# epoch : 53/200
# train_loss : 0.0001615644 test_loss : 0.0023846044
# -------------------------------------------------------------------------------------------------
# epoch : 54/200
# train_loss : 0.00015925185 test_loss : 0.0023647547
# -------------------------------------------------------------------------------------------------
# epoch : 55/200
# train_loss : 0.00015708533 test_loss : 0.0023510137
# -------------------------------------------------------------------------------------------------
# epoch : 56/200
# train_loss : 0.00015514898 test_loss : 0.002342059
# -------------------------------------------------------------------------------------------------
# epoch : 57/200
# train_loss : 0.00015357569 test_loss : 0.002338161
# -------------------------------------------------------------------------------------------------
# epoch : 58/200
# train_loss : 0.00015242706 test_loss : 0.002335884
# -------------------------------------------------------------------------------------------------
# epoch : 59/200
# train_loss : 0.00015172522 test_loss : 0.0023327512
# -------------------------------------------------------------------------------------------------
# epoch : 60/200
# train_loss : 0.00015125284 test_loss : 0.002329237
# -------------------------------------------------------------------------------------------------
# epoch : 61/200
# train_loss : 0.00015093444 test_loss : 0.0023250217
# -------------------------------------------------------------------------------------------------
# epoch : 62/200
# train_loss : 0.00015058299 test_loss : 0.0023189585
# -------------------------------------------------------------------------------------------------
# epoch : 63/200
# train_loss : 0.00015020624 test_loss : 0.002310846
# -------------------------------------------------------------------------------------------------
# epoch : 64/200
# train_loss : 0.00014976606 test_loss : 0.0023011689
# -------------------------------------------------------------------------------------------------
# epoch : 65/200
# train_loss : 0.00014924965 test_loss : 0.0022900891
# -------------------------------------------------------------------------------------------------
# epoch : 66/200
# train_loss : 0.00014863595 test_loss : 0.0022791333
# -------------------------------------------------------------------------------------------------
# epoch : 67/200
# train_loss : 0.00014793087 test_loss : 0.002269802
# -------------------------------------------------------------------------------------------------
# epoch : 68/200
# train_loss : 0.0001471779 test_loss : 0.0022622987
# -------------------------------------------------------------------------------------------------
# epoch : 69/200
# train_loss : 0.0001464025 test_loss : 0.0022579858
# -------------------------------------------------------------------------------------------------
# epoch : 70/200
# train_loss : 0.00014565473 test_loss : 0.002256203
# -------------------------------------------------------------------------------------------------
# epoch : 71/200
# train_loss : 0.00014495813 test_loss : 0.0022564284
# -------------------------------------------------------------------------------------------------
# epoch : 72/200
# train_loss : 0.00014435372 test_loss : 0.00225936
# -------------------------------------------------------------------------------------------------
# epoch : 73/200
# train_loss : 0.00014383654 test_loss : 0.0022627325
# -------------------------------------------------------------------------------------------------
# epoch : 74/200
# train_loss : 0.00014340009 test_loss : 0.0022692706
# -------------------------------------------------------------------------------------------------
# epoch : 75/200
# train_loss : 0.00014305765 test_loss : 0.002276351
# -------------------------------------------------------------------------------------------------
# epoch : 76/200
# train_loss : 0.00014279516 test_loss : 0.0022826395
# -------------------------------------------------------------------------------------------------
# epoch : 77/200
# train_loss : 0.00014257708 test_loss : 0.0022867837
# -------------------------------------------------------------------------------------------------
# epoch : 78/200
# train_loss : 0.00014238659 test_loss : 0.002288484
# -------------------------------------------------------------------------------------------------
# epoch : 79/200
# train_loss : 0.00014216105 test_loss : 0.0022876512
# -------------------------------------------------------------------------------------------------
# epoch : 80/200
# train_loss : 0.00014187829 test_loss : 0.002284501
# -------------------------------------------------------------------------------------------------
# epoch : 81/200
# train_loss : 0.00014153935 test_loss : 0.002279683
# -------------------------------------------------------------------------------------------------
# epoch : 82/200
# train_loss : 0.0001411602 test_loss : 0.002273344
# -------------------------------------------------------------------------------------------------
# epoch : 83/200
# train_loss : 0.00014075717 test_loss : 0.0022657167
# -------------------------------------------------------------------------------------------------
# epoch : 84/200
# train_loss : 0.00014034778 test_loss : 0.0022574079
# -------------------------------------------------------------------------------------------------
# epoch : 85/200
# train_loss : 0.00013995456 test_loss : 0.0022495487
# -------------------------------------------------------------------------------------------------
# epoch : 86/200
# train_loss : 0.00013960018 test_loss : 0.0022416993
# -------------------------------------------------------------------------------------------------
# epoch : 87/200
# train_loss : 0.00013927917 test_loss : 0.0022349092
# -------------------------------------------------------------------------------------------------
# epoch : 88/200
# train_loss : 0.00013900377 test_loss : 0.0022292964
# -------------------------------------------------------------------------------------------------
# epoch : 89/200
# train_loss : 0.00013874796 test_loss : 0.0022249336
# -------------------------------------------------------------------------------------------------
# epoch : 90/200
# train_loss : 0.00013850656 test_loss : 0.0022215757
# -------------------------------------------------------------------------------------------------
# epoch : 91/200
# train_loss : 0.00013828075 test_loss : 0.0022187827
# -------------------------------------------------------------------------------------------------
# epoch : 92/200
# train_loss : 0.00013805587 test_loss : 0.002216924
# -------------------------------------------------------------------------------------------------
# epoch : 93/200
# train_loss : 0.0001378233 test_loss : 0.002215702
# -------------------------------------------------------------------------------------------------
# epoch : 94/200
# train_loss : 0.00013758533 test_loss : 0.0022149044
# -------------------------------------------------------------------------------------------------
# epoch : 95/200
# train_loss : 0.00013734205 test_loss : 0.002214344
# -------------------------------------------------------------------------------------------------
# epoch : 96/200
# train_loss : 0.00013709198 test_loss : 0.0022140911
# -------------------------------------------------------------------------------------------------
# epoch : 97/200
# train_loss : 0.00013684279 test_loss : 0.0022143207
# -------------------------------------------------------------------------------------------------
# epoch : 98/200
# train_loss : 0.00013660376 test_loss : 0.0022145838
# -------------------------------------------------------------------------------------------------
# epoch : 99/200
# train_loss : 0.00013636737 test_loss : 0.0022148157
# -------------------------------------------------------------------------------------------------
# epoch : 100/200
# train_loss : 0.00013613702 test_loss : 0.0022150148
# -------------------------------------------------------------------------------------------------
# epoch : 101/200
# train_loss : 0.00013591361 test_loss : 0.002215502
# -------------------------------------------------------------------------------------------------
# epoch : 102/200
# train_loss : 0.00013569515 test_loss : 0.0022161184
# -------------------------------------------------------------------------------------------------
# epoch : 103/200
# train_loss : 0.00013548808 test_loss : 0.0022164406
# -------------------------------------------------------------------------------------------------
# epoch : 104/200
# train_loss : 0.00013529783 test_loss : 0.0022163677
# -------------------------------------------------------------------------------------------------
# epoch : 105/200
# train_loss : 0.00013511177 test_loss : 0.0022159852
# -------------------------------------------------------------------------------------------------
# epoch : 106/200
# train_loss : 0.00013492517 test_loss : 0.002215126
# -------------------------------------------------------------------------------------------------
# epoch : 107/200
# train_loss : 0.00013474088 test_loss : 0.0022138744
# -------------------------------------------------------------------------------------------------
# epoch : 108/200
# train_loss : 0.00013456085 test_loss : 0.0022122262
# -------------------------------------------------------------------------------------------------
# epoch : 109/200
# train_loss : 0.00013438024 test_loss : 0.0022103635
# -------------------------------------------------------------------------------------------------
# epoch : 110/200
# train_loss : 0.00013420041 test_loss : 0.0022086916
# -------------------------------------------------------------------------------------------------
# epoch : 111/200
# train_loss : 0.00013402196 test_loss : 0.0022067777
# -------------------------------------------------------------------------------------------------
# epoch : 112/200
# train_loss : 0.00013384297 test_loss : 0.0022045912
# -------------------------------------------------------------------------------------------------
# epoch : 113/200
# train_loss : 0.00013366596 test_loss : 0.002202076
# -------------------------------------------------------------------------------------------------
# epoch : 114/200
# train_loss : 0.00013349709 test_loss : 0.0021993576
# -------------------------------------------------------------------------------------------------
# epoch : 115/200
# train_loss : 0.00013332997 test_loss : 0.0021965054
# -------------------------------------------------------------------------------------------------
# epoch : 116/200
# train_loss : 0.00013316557 test_loss : 0.0021936821
# -------------------------------------------------------------------------------------------------
# epoch : 117/200
# train_loss : 0.0001330042 test_loss : 0.0021907662
# -------------------------------------------------------------------------------------------------
# epoch : 118/200
# train_loss : 0.00013284497 test_loss : 0.0021879566
# -------------------------------------------------------------------------------------------------
# epoch : 119/200
# train_loss : 0.00013268889 test_loss : 0.00218537
# -------------------------------------------------------------------------------------------------
# epoch : 120/200
# train_loss : 0.00013253842 test_loss : 0.0021831442
# -------------------------------------------------------------------------------------------------
# epoch : 121/200
# train_loss : 0.00013239343 test_loss : 0.002181321
# -------------------------------------------------------------------------------------------------
# epoch : 122/200
# train_loss : 0.00013224872 test_loss : 0.0021797398
# -------------------------------------------------------------------------------------------------
# epoch : 123/200
# train_loss : 0.00013210395 test_loss : 0.0021783358
# -------------------------------------------------------------------------------------------------
# epoch : 124/200
# train_loss : 0.00013195895 test_loss : 0.0021770732
# -------------------------------------------------------------------------------------------------
# epoch : 125/200
# train_loss : 0.0001318154 test_loss : 0.0021758778
# -------------------------------------------------------------------------------------------------
# epoch : 126/200
# train_loss : 0.0001316757 test_loss : 0.0021746207
# -------------------------------------------------------------------------------------------------
# epoch : 127/200
# train_loss : 0.0001315374 test_loss : 0.0021732922
# -------------------------------------------------------------------------------------------------
# epoch : 128/200
# train_loss : 0.00013140193 test_loss : 0.0021719034
# -------------------------------------------------------------------------------------------------
# epoch : 129/200
# train_loss : 0.00013126833 test_loss : 0.0021704375
# -------------------------------------------------------------------------------------------------
# epoch : 130/200
# train_loss : 0.00013113552 test_loss : 0.0021688358
# -------------------------------------------------------------------------------------------------
# epoch : 131/200
# train_loss : 0.000131003 test_loss : 0.002167149
# -------------------------------------------------------------------------------------------------
# epoch : 132/200
# train_loss : 0.00013087157 test_loss : 0.0021654512
# -------------------------------------------------------------------------------------------------
# epoch : 133/200
# train_loss : 0.00013074143 test_loss : 0.0021637566
# -------------------------------------------------------------------------------------------------
# epoch : 134/200
# train_loss : 0.00013061179 test_loss : 0.0021621005
# -------------------------------------------------------------------------------------------------
# epoch : 135/200
# train_loss : 0.00013048312 test_loss : 0.0021604141
# -------------------------------------------------------------------------------------------------
# epoch : 136/200
# train_loss : 0.00013035446 test_loss : 0.0021586423
# -------------------------------------------------------------------------------------------------
# epoch : 137/200
# train_loss : 0.00013022558 test_loss : 0.00215679
# -------------------------------------------------------------------------------------------------
# epoch : 138/200
# train_loss : 0.0001300967 test_loss : 0.0021549272
# -------------------------------------------------------------------------------------------------
# epoch : 139/200
# train_loss : 0.0001299679 test_loss : 0.0021530522
# -------------------------------------------------------------------------------------------------
# epoch : 140/200
# train_loss : 0.00012983872 test_loss : 0.002151164
# -------------------------------------------------------------------------------------------------
# epoch : 141/200
# train_loss : 0.00012971053 test_loss : 0.0021491789
# -------------------------------------------------------------------------------------------------
# epoch : 142/200
# train_loss : 0.0001295851 test_loss : 0.0021471246
# -------------------------------------------------------------------------------------------------
# epoch : 143/200
# train_loss : 0.0001294594 test_loss : 0.0021450084
# -------------------------------------------------------------------------------------------------
# epoch : 144/200
# train_loss : 0.00012933307 test_loss : 0.0021430815
# -------------------------------------------------------------------------------------------------
# epoch : 145/200
# train_loss : 0.00012920733 test_loss : 0.0021413532
# -------------------------------------------------------------------------------------------------
# epoch : 146/200
# train_loss : 0.00012908207 test_loss : 0.0021396058
# -------------------------------------------------------------------------------------------------
# epoch : 147/200
# train_loss : 0.00012895817 test_loss : 0.002137824
# -------------------------------------------------------------------------------------------------
# epoch : 148/200
# train_loss : 0.00012883403 test_loss : 0.0021360067
# -------------------------------------------------------------------------------------------------
# epoch : 149/200
# train_loss : 0.0001287106 test_loss : 0.002134159
# -------------------------------------------------------------------------------------------------
# epoch : 150/200
# train_loss : 0.00012858685 test_loss : 0.0021322793
# -------------------------------------------------------------------------------------------------
# epoch : 151/200
# train_loss : 0.0001284634 test_loss : 0.0021303499
# -------------------------------------------------------------------------------------------------
# epoch : 152/200
# train_loss : 0.00012834159 test_loss : 0.002128427
# -------------------------------------------------------------------------------------------------
# epoch : 153/200
# train_loss : 0.00012822066 test_loss : 0.0021265084
# -------------------------------------------------------------------------------------------------
# epoch : 154/200
# train_loss : 0.00012810115 test_loss : 0.0021245186
# -------------------------------------------------------------------------------------------------
# epoch : 155/200
# train_loss : 0.00012798085 test_loss : 0.0021225074
# -------------------------------------------------------------------------------------------------
# epoch : 156/200
# train_loss : 0.00012786203 test_loss : 0.0021203659
# -------------------------------------------------------------------------------------------------
# epoch : 157/200
# train_loss : 0.00012774611 test_loss : 0.0021180704
# -------------------------------------------------------------------------------------------------
# epoch : 158/200
# train_loss : 0.00012763066 test_loss : 0.0021158233
# -------------------------------------------------------------------------------------------------
# epoch : 159/200
# train_loss : 0.00012751868 test_loss : 0.0021138312
# -------------------------------------------------------------------------------------------------
# epoch : 160/200
# train_loss : 0.00012740819 test_loss : 0.0021120987
# -------------------------------------------------------------------------------------------------
# epoch : 161/200
# train_loss : 0.00012729724 test_loss : 0.0021105367
# -------------------------------------------------------------------------------------------------
# epoch : 162/200
# train_loss : 0.00012718662 test_loss : 0.0021090794
# -------------------------------------------------------------------------------------------------
# epoch : 163/200
# train_loss : 0.00012708004 test_loss : 0.0021075946
# -------------------------------------------------------------------------------------------------
# epoch : 164/200
# train_loss : 0.00012697099 test_loss : 0.0021061292
# -------------------------------------------------------------------------------------------------
# epoch : 165/200
# train_loss : 0.00012686451 test_loss : 0.0021045026
# -------------------------------------------------------------------------------------------------
# epoch : 166/200
# train_loss : 0.00012675897 test_loss : 0.0021027147
# -------------------------------------------------------------------------------------------------
# epoch : 167/200
# train_loss : 0.00012665273 test_loss : 0.0021009708
# -------------------------------------------------------------------------------------------------
# epoch : 168/200
# train_loss : 0.00012654776 test_loss : 0.002099223
# -------------------------------------------------------------------------------------------------
# epoch : 169/200
# train_loss : 0.00012644417 test_loss : 0.0020972674
# -------------------------------------------------------------------------------------------------
# epoch : 170/200
# train_loss : 0.00012634078 test_loss : 0.0020952504
# -------------------------------------------------------------------------------------------------
# epoch : 171/200
# train_loss : 0.00012624086 test_loss : 0.0020932427
# -------------------------------------------------------------------------------------------------
# epoch : 172/200
# train_loss : 0.00012614192 test_loss : 0.0020912343
# -------------------------------------------------------------------------------------------------
# epoch : 173/200
# train_loss : 0.00012604438 test_loss : 0.0020892036
# -------------------------------------------------------------------------------------------------
# epoch : 174/200
# train_loss : 0.00012594748 test_loss : 0.0020872022
# -------------------------------------------------------------------------------------------------
# epoch : 175/200
# train_loss : 0.00012585141 test_loss : 0.002085178
# -------------------------------------------------------------------------------------------------
# epoch : 176/200
# train_loss : 0.00012575556 test_loss : 0.0020832315
# -------------------------------------------------------------------------------------------------
# epoch : 177/200
# train_loss : 0.00012565935 test_loss : 0.0020815185
# -------------------------------------------------------------------------------------------------
# epoch : 178/200
# train_loss : 0.00012556347 test_loss : 0.002079758
# -------------------------------------------------------------------------------------------------
# epoch : 179/200
# train_loss : 0.0001254687 test_loss : 0.0020777932
# -------------------------------------------------------------------------------------------------
# epoch : 180/200
# train_loss : 0.00012537478 test_loss : 0.0020757099
# -------------------------------------------------------------------------------------------------
# epoch : 181/200
# train_loss : 0.00012528106 test_loss : 0.0020735615
# -------------------------------------------------------------------------------------------------
# epoch : 182/200
# train_loss : 0.0001251884 test_loss : 0.0020715576
# -------------------------------------------------------------------------------------------------
# epoch : 183/200
# train_loss : 0.00012509755 test_loss : 0.0020694945
# -------------------------------------------------------------------------------------------------
# epoch : 184/200
# train_loss : 0.00012500683 test_loss : 0.0020673135
# -------------------------------------------------------------------------------------------------
# epoch : 185/200
# train_loss : 0.00012491555 test_loss : 0.0020649845
# -------------------------------------------------------------------------------------------------
# epoch : 186/200
# train_loss : 0.0001248254 test_loss : 0.0020624355
# -------------------------------------------------------------------------------------------------
# epoch : 187/200
# train_loss : 0.00012473535 test_loss : 0.0020599354
# -------------------------------------------------------------------------------------------------
# epoch : 188/200
# train_loss : 0.0001246466 test_loss : 0.0020576396
# -------------------------------------------------------------------------------------------------
# epoch : 189/200
# train_loss : 0.00012455917 test_loss : 0.0020556366
# -------------------------------------------------------------------------------------------------
# epoch : 190/200
# train_loss : 0.00012447138 test_loss : 0.0020537402
# -------------------------------------------------------------------------------------------------
# epoch : 191/200
# train_loss : 0.0001243838 test_loss : 0.0020521819
# -------------------------------------------------------------------------------------------------
# epoch : 192/200
# train_loss : 0.00012429676 test_loss : 0.0020506906
# -------------------------------------------------------------------------------------------------
# epoch : 193/200
# train_loss : 0.0001242108 test_loss : 0.0020493055
# -------------------------------------------------------------------------------------------------
# epoch : 194/200
# train_loss : 0.0001241278 test_loss : 0.0020476507
# -------------------------------------------------------------------------------------------------
# epoch : 195/200
# train_loss : 0.00012404629 test_loss : 0.0020457197
# -------------------------------------------------------------------------------------------------
# epoch : 196/200
# train_loss : 0.00012396462 test_loss : 0.0020434365
# -------------------------------------------------------------------------------------------------
# epoch : 197/200
# train_loss : 0.00012388242 test_loss : 0.0020409396
# -------------------------------------------------------------------------------------------------
# epoch : 198/200
# train_loss : 0.00012380058 test_loss : 0.0020385727
# -------------------------------------------------------------------------------------------------
# epoch : 199/200
# train_loss : 0.00012372033 test_loss : 0.0020363242
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Visualisation des performances d'entraînement

# %%
loss = history_train_loss
val_loss = history_test_loss

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Mean Square Error')

plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Visualisation des données de test

# %% [markdown]
# **Utilisez** la méthode `forward` pour obtenir les prédictions sur le jeu de données de test.

# %%
dataloader_train = torch.utils.data.DataLoader(x_training,
                                                batch_size=len(x_training),
                                                shuffle=False)

# %%
for x, y in dataloader_train:
  pred = model.forward(x).detach().numpy()
  break

# %%
plt.figure(figsize=(20,10))
plt.plot(y.detach().numpy(), color = 'black', label = 'Delhi Mean Temperature')
plt.plot(pred, color = 'green', label = 'Predicted Delhi Mean Temperature')
plt.title('Delhi Mean Temp Prediction')
plt.xlabel('Time')
plt.ylabel('Mean Temp')
plt.legend()
plt.show()

# %%
for x, y in dataloader_test:
  pred = model.forward(x).detach().numpy()
  break

# %%
plt.figure(figsize=(20,10))
plt.plot(y.detach().numpy(), color = 'black', label = 'Delhi Mean Temperature')
plt.plot(pred, color = 'green', label = 'Predicted Delhi Mean Temperature')
plt.title('Delhi Mean Temp Prediction')
plt.xlabel('Time')
plt.ylabel('Mean Temp')
plt.legend()
plt.show()
